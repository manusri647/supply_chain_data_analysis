# %% [markdown]
# To install pandas

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install pandas #install pandas

# %% [markdown]
# This imports the pandas library and gives it the alias pd, which is a common convention.
#
# Pandas is used for working with tabular data (rows and columns), such as CSV, Excel, SQL, etc.

# %%
import pandas as pd#Loads a data-handling tool called Pandas,
df = pd.read_csv('supply_chain_data.csv')# Reads your CSV file (like an Excel sheet) into our system
df# This is now the name of your dataset in the system, so we can clean it, analyze it, and create reports.
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %% [markdown]
# see data types (important before analysis or plotting)
#
# Get row & column count
#
# Verify large data memory usage

# %%
df.info()#information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %% [markdown]
# Helps you identify missing data before analysis or modeling.

# %%
df.isnull().sum()# where and how much data is incomplete, so we know what needs cleaning before analysis.
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %% [markdown]
# To check for and clean duplicate data before analysis or modeling.
#
# Helps ensure data quality.

# %%
df.duplicated().sum()#Counts how many missing values there are in each column
# Out:
# np.int64(0)

# %% [markdown]
#  Pandas generates summary statistics of the DataFrame’s columns, such as count, mean, std, min, and max for numeric data.
# It helps quickly understand data distribution, spread, and central tendency.

# %%
df.describe()# Generate summary statistics for all numeric columns (count, mean, std, min, quartiles, max)
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %% [markdown]
# Which product sales most

# %% [markdown]
# This code creates a sky-blue bar chart using Seaborn to visualize the number of products sold by product type with labeled axes and a title

# %%
import seaborn as sns#Sets up a clean chart space of a specific size
import matplotlib.pyplot as plt#Sets up a clean chart space of a specific size
plt.figure(figsize=(5, 4))#Creates a new figure (canvas) for the plot.
sns.barplot(x='Product type', y='Number of products sold', data=df, color='skyblue')#creating chart
plt.title('product sales')#title
plt.xlabel('Product Type')#xlable title
plt.ylabel('Total Number of Products Sold')#y lable title
plt.show()#show

# %% [markdown]
# Which product has least revenue

# %% [markdown]
# This code creates a red bar chart to compare product prices by type and identify the product with the least revenue potential.

# %%
plt.figure(figsize=(10,5))# Sets a wide chart size for better readability
sns.barplot(x='Product type', y='Price',data=df,color='red')# makes the bars stand out in red
plt.title('Which product has least revenue')#Adds a title indicating the goal: finding which product might have the least revenue potential
plt.xlabel('product type')#xlable name
plt.ylabel('price')#ylable
plt.grid(True)#Adds grid lines for easier value comparison
plt.show()#show chart

# %% [markdown]
# Which product is more costly

# %% [markdown]
# This code generates a pie chart showing the percentage distribution of average prices across different product types with customized colors and labels

# %%
plt.figure(figsize=(8,5))#Sets the size of the chart
plt.pie(average_price_by_product, labels=average_price_by_product.index, autopct='%1.1f%%', colors=['violet', 'blue', 'green', 'orange', 'red', 'purple', 'brown', 'pink', 'gray', 'olive'])
plt.title('Average Price Distribution by Product Type')#Adds a descriptive title to the chart
plt.show()#show

# %% [markdown]
# This code creates a grouped bar chart comparing revenue generated by product type and transportation modes, with labeled axes, title, and grid.

# %%
plt.figure(figsize=(10, 6))#Creates a new figure for the plot
sns.barplot(x='Product type', y='Revenue generated', data=df,hue='Transportation modes')#Bars are grouped and colored based on transportation mode
plt.title('Revenue Generated vs. Number of Products Sold')#Sets the title of the chart
plt.xlabel('Number of Products Sold')#xlable name
plt.ylabel('Revenue Generated')#ylable name
plt.grid(True)#Turns on grid lines for better readability
plt.show()#Displays the chart

# %% [markdown]
# Which location has more orders

# %% [markdown]
# This code creates a line plot showing order quantities across different locations with labeled axes and a title

# %%
sns.lineplot(x='Location', y='Order quantities', data=df)#Create a line plot showing Order Quantities across different Locations
plt.xlabel('Location')#Label the X-axis as 'Location'
plt.ylabel('Order quantities')#Label the Y-axis as 'Order quantities
plt.title('Order Quantities by Location')## Set the plot title
plt.show()#Display the plot

# %% [markdown]
# This code creates a box plot to visualize the distribution of revenue generated across different customer demographics.

# %%
plt.figure(figsize=(12, 6))# Set the figure size to 12 inches wide and 6 inches tall
sns.boxplot(x='Customer demographics',y='Revenue generated',data=df)# Create a boxplot to show the distribution of Revenue generated across different Customer demographics
plt.xlabel('Customer demographics')# Label the X-axis
plt.ylabel('Revenue generated')# Label the Y-axis
plt.title('Customer demographics and Revenue generated')# Set the title of the plot
plt.show()# Display the plot

# %% [markdown]
# This code creates a green histogram to show the frequency distribution of manufacturing costs with labeled axes, title, and a horizontal grid.

# %%
plt.figure(figsize=(10, 6))# Set the figure size to 10 inches wide and 6 inches tall
plt.hist(df['Manufacturing costs'], bins=20, color='green')# Create a histogram for the 'Manufacturing costs' column with 20 bins and green bars
plt.title('Manufacturing costs')# Set the title of the plot
plt.xlabel('Manufacturing costs')# Label the X-axis
plt.ylabel('Frequency')# Label the Y-axis (frequency of data points in each bin)
plt.grid(axis='y')# Display horizontal grid lines for better readability (only along Y-axis)
plt.show()# Show the plot

# %% [markdown]
# This code creates a grouped purple bar chart comparing manufacturing costs by product type across different locations.

# %%
plt.figure(figsize=(12, 6))# Set the figure size to 12 inches wide and 6 inches tall
sns.barplot(x='Product type',y='Manufacturing costs',data=df, color='purple',hue='Location')# Create a bar plot showing Manufacturing Costs for each Product type
plt.xlabel('Product Type')# Label the X-axis as 'Product Type'
plt.ylabel('Manufacturing Costs')# Label the Y-axis as 'Manufacturing Costs'
plt.title('Manufacturing Costs by Product Type')# Set the title of the plot
plt.show()# Display the plot
# Out:
# /tmp/ipython-input-52-606566953.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:purple'` for the same effect.
#
#   sns.barplot(x='Product type',y='Manufacturing costs',data=df, color='purple',hue='Location')

# %% [markdown]
# This code generates a heatmap to show the correlation between defect rates, manufacturing costs, and revenue generated with annotated values and a coolwarm color scheme.

# %%
heatmap_data = df[['Defect rates', 'Manufacturing costs','Revenue generated']]# Select only the relevant columns for correlation analysis
correlation_matrix_subset = heatmap_data.corr()# Calculate the correlation matrix for the selected columns
plt.figure(figsize=(6, 4))# Set the figure size to 6 inches wide and 4 inches tall
sns.heatmap(correlation_matrix_subset, annot=True, cmap='coolwarm', fmt=".2f")# Create a heatmap of the correlation matrix
plt.title('Correlation Heatmap: Defect Rates vs. Manufacturing Costs')# Set the title of the heatmap
plt.show()# Display the plot

# %% [markdown]
# This code creates an orange count plot to display the frequency of different inspection results across the dataset.

# %%
plt.figure(figsize=(12, 6))# Set the figure size to 12 inches wide and 6 inches tall
sns.countplot(x="Inspection results", data=df, color='orange')# Create a count plot showing the frequency of each Inspection result
plt.xlabel('Inspection Results')# Label the X-axis
plt.ylabel('Count')# Label the Y-axis
plt.title('Count of Inspection Results by Location')# Set the title of the plot
plt.show()# Display the plot

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 25))
axes = axes.flatten()

# Plot 1: Total Number of Products Sold by Product Type
sns.barplot(x='Product type', y='Number of products sold', data=df, color='skyblue', ax=axes[0])
axes[0].set_title('Total Number of Products Sold by Product Type')
axes[0].set_xlabel('Product Type')
axes[0].set_ylabel('Total Number of Products Sold')

# Plot 2: Price by Product Type
sns.barplot(x='Product type', y='Price',data=df,color='red', ax=axes[1])
axes[1].set_title('Price by Product Type')
axes[1].set_xlabel('Product Type')
axes[1].set_ylabel('Price')
axes[1].grid(True)

# Plot 3: Average Price Distribution by Product Type (Pie Chart)
axes[2].pie(average_price_by_product, labels=average_price_by_product.index, autopct='%1.1f%%', colors=['violet', 'blue', 'green', 'orange', 'red', 'purple', 'brown', 'pink', 'gray', 'olive'])
axes[2].set_title('Average Price Distribution by Product Type')

# Plot 4: Revenue Generated vs. Number of Products Sold with Transportation Modes Hue
sns.barplot(x='Product type', y='Revenue generated', data=df,hue='Transportation modes', ax=axes[3])
axes[3].set_title('Revenue Generated by Product Type and Transportation Mode')
axes[3].set_xlabel('Product Type')
axes[3].set_ylabel('Revenue Generated')
axes[3].grid(True)

# Plot 5: Order Quantities by Location
sns.lineplot(x='Location', y='Order quantities', data=df, ax=axes[4])
axes[4].set_title('Order Quantities by Location')
axes[4].set_xlabel('Location')
axes[4].set_ylabel('Order quantities')

# Plot 6: Customer demographics and Revenue generated (Box Plot)
sns.boxplot(x='Customer demographics',y='Revenue generated',data=df, ax=axes[5])
axes[5].set_title('Revenue Generated by Customer Demographics')
axes[5].set_xlabel('Customer demographics')
axes[5].set_ylabel('Revenue Generated')

# Plot 7: Manufacturing costs histogram
axes[6].hist(df['Manufacturing costs'], bins=20, color='green')
axes[6].set_title('Manufacturing costs')
axes[6].set_xlabel('Manufacturing costs')
axes[6].set_ylabel('Frequency')
axes[6].grid(axis='y')

# Plot 8: Manufacturing Costs by Product Type and Location Hue
sns.barplot(x='Product type',y='Manufacturing costs',data=df, color='purple',hue='Location', ax=axes[7])
axes[7].set_title('Manufacturing Costs by Product Type and Location')
axes[7].set_xlabel('Product Type')
axes[7].set_ylabel('Manufacturing Costs')

# Plot 9: Correlation Heatmap: Defect Rates vs. Manufacturing Costs vs. Revenue Generated
heatmap_data = df[['Defect rates', 'Manufacturing costs','Revenue generated']]
correlation_matrix_subset = heatmap_data.corr()
sns.heatmap(correlation_matrix_subset, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[8])
axes[8].set_title('Correlation Heatmap')

# Plot 10: Count of Inspection Results
sns.countplot(x="Inspection results", data=df, color='orange', ax=axes[9])
axes[9].set_title('Count of Inspection Results')
axes[9].set_xlabel('Inspection Results')
axes[9].set_ylabel('Count')


plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-61-772167987.py:48: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:purple'` for the same effect.
#
#   sns.barplot(x='Product type',y='Manufacturing costs',data=df, color='purple',hue='Location', ax=axes[7])

# %% [markdown]
# which product sales most -  skincare
#
# Which product has least revenue -  haircare
#
# most costly product - cosmetics
#
# Transpotation mode and revenue  -  Road (cosmetics)
#
# Which location has more orders -  chennai
#
# Customer demographics and Revenue generated -  unknown and next non - binary
#
# Frequency of  Manufacturing costs - 98
#
# Manufacturing Costs by Product Type-  skincare (bangalore)
#
# Correlation Heatmap: Defect Rates vs. Manufacturing Costs
#
# Count of Inspection Results by Location - pending

# %% [markdown]
# Total Products Sold by Product Type
#
# Shows which product categories (e.g., skincare, haircare) have the highest sales volume.
#
# Helps identify top-selling products and potential underperformers.
#
# Price by Product Type
#
# Compares the average price across product categories.
#
# Useful for pricing strategy and identifying categories with low or high margins.
#
# Average Price Distribution (Pie Chart)
#
# Displays how each product type contributes to the overall average pricing mix.
#
# Highlights categories with premium vs. budget pricing.
#
# Revenue by Product Type & Transportation Mode
#
# Shows how revenue changes based on both product type and delivery method (e.g., road, air, rail).
#
# Can guide decisions on the most profitable transport modes for each category.
#
# Order Quantities by Location
#
# Tracks how many products are ordered from each location.
#
# Helps plan regional inventory and marketing strategies.
#
# Revenue by Customer Demographics
#
# Shows which customer groups (e.g., male, female, non-binary, unknown) bring in the most revenue.
#
# Supports targeted marketing and product positioning.
#
# Manufacturing Costs (Histogram)
#
# Visualizes how manufacturing costs are distributed across all products.
#
# Helps spot cost outliers that may need cost optimization.
#
# Manufacturing Costs by Product Type & Location
#
# Compares manufacturing costs for each category, broken down by location.
#
# Reveals cost differences between production sites.
#
# Correlation Heatmap
#
# Shows the relationship between defect rates, manufacturing costs, and revenue.
#
# Identifies whether higher costs or defects impact revenue significantly.
#
# Inspection Results Count
#
# Displays the number of products that passed, failed, or are pending inspection.
#
# Highlights quality control performance.
